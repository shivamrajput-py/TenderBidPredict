# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
electric=pd.read_csv('ElectricalWorks.csv')

# %%
electric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3292 entries, 0 to 3291
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             3292 non-null   object
#  1   title          3045 non-null   object
#  2   org            3292 non-null   object
#  3   gov_est_price  3292 non-null   float64
#  4   bid_won_price  3292 non-null   float64
#  5   percentage     3291 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 154.4+ KB

# %%
electric.head()
# Out:
#                  id                                              title  org  \
# 0  2024_PWD_89852_1  AMC of one NO. 13 passenger stretcher elevator...  PWD
# 1  2024_PWD_89570_1  Construction of Senior Secondary School buildi...  PWD
# 2  2024_PWD_89567_1  Construction of Senior Secondary School buildi...  PWD
# 3  2024_PWD_89521_1  Construction of multipurpose Hall Govt. P.G. C...  PWD
# 4  2024_PWD_88836_1  Providing additional fire fighting accessories...  PWD
#
#    gov_est_price  bid_won_price  percentage
# 0       211776.0       210505.0       -0.60
# 1       937508.0       773444.0      -17.50
# 2       866680.0       723678.0      -16.50
# 3      2342478.0      1988295.0      -15.12
# 4       979326.0       979326.0        0.00

# %%
x=electric.drop(['id','title','gov_est_price','percentage','org'],axis=1)
y=electric['gov_est_price']

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=2)

# %%
linear = LinearRegression()

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = linear.predict(x_test)

# %%
r2_score = metrics.r2_score(y_test,prediction)

# %%
print(r2_score)
# Out:
# 0.9961391323852672

# %%
print(x_test)
# Out:
#       bid_won_price
# 240        488449.0
# 1768      4748925.0
# 110        191808.0
# 1987       879285.0
# 2900       689779.0
# ...             ...
# 1423       774593.0
# 1127       175210.0
# 515        712324.0
# 1162       336001.0
# 966        450532.0
#
# [659 rows x 1 columns]

# %%
print(y_test)
# Out:
# 240      474231.0
# 1768    5395630.0
# 110      199800.0
# 1987     677001.0
# 2900     918030.0
#           ...
# 1423     739822.0
# 1127     196982.0
# 515      708780.0
# 1162     346500.0
# 966      433410.0
# Name: gov_est_price, Length: 659, dtype: float64

# %%
custom_re_df=pd.DataFrame(data={'bid_won_price':[774593.0]})
print(custom_re_df)
# Out:
#    bid_won_price
# 0       774593.0

# %%
custom_pred=linear.predict(custom_re_df)
print(custom_pred)
# Out:
# [1028131.98255539]
